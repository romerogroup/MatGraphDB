# %%
from matgraphdb.graph_kit.data import DataGenerator
from matgraphdb.graph_kit.graphs import GraphManager

# %%
generator=DataGenerator()
manager=GraphManager()

# %%
node_names=manager.list_nodes()
relationship_names=manager.list_relationships()

print('-'*100)
print('Nodes Types')
print('-'*100)
for i,node_name in enumerate(node_names):
    print(i,node_name)

print('-'*100)
print('Relationships')
print('-'*100)
for i,relationship_name in enumerate(relationship_names):
    print(i,relationship_name)
print('-'*100)
# Out:
# ----------------------------------------------------------------------------------------------------
# Nodes Types
# ----------------------------------------------------------------------------------------------------
# 0 CHEMENV
# 1 CRYSTAL_SYSTEM
# 2 ELEMENT
# 3 LATTICE
# 4 MAGNETIC_STATE
# 5 MATERIAL
# 6 OXIDATION_STATE
# 7 SITE
# 8 SPACE_GROUP
# 9 SPG_WYCKOFF
# ----------------------------------------------------------------------------------------------------
# Relationships
# ----------------------------------------------------------------------------------------------------
# 0 CHEMENV-ELECTRIC_CONNECTS-CHEMENV
# 1 CHEMENV-GEOMETRIC_CONNECTS-CHEMENV
# 2 CHEMENV-GEOMETRIC_ELECTRIC_CONNECTS-CHEMENV
# 3 ELEMENT-CAN_OCCUR-CHEMENV
# 4 ELEMENT-CAN_OCCUR-OXIDATION_STATE
# 5 ELEMENT-ELECTRIC_CONNECTS-ELEMENT
# 6 ELEMENT-GEOMETRIC_CONNECTS-ELEMENT
# 7 ELEMENT-GEOMETRIC_ELECTRIC_CONNECTS-ELEMENT
# 8 ELEMENT-GROUP_PERIOD_CONNECTS-ELEMENT
# 9 MATERIAL-HAS-CHEMENV
# 10 MATERIAL-HAS-CRYSTAL_SYSTEM
# 11 MATERIAL-HAS-ELEMENT
# 12 MATERIAL-HAS-LATTICE
# 13 MATERIAL-HAS-SITE
# 14 MATERIAL-HAS-SPACE_GROUP
# ----------------------------------------------------------------------------------------------------

# %%
node_files=manager.get_node_filepaths()
relationship_files=manager.get_relationship_filepaths()

print('-'*100)
print('Nodes Types')
print('-'*100)
for i,node_file in enumerate(node_files):
    print(i,node_file)

print('-'*100)
print('Relationships')
print('-'*100)
for i,relationship_file in enumerate(relationship_files):
    print(i,relationship_file)
print('-'*100)
# Out:
# ----------------------------------------------------------------------------------------------------
# Nodes Types
# ----------------------------------------------------------------------------------------------------
# 0 Z:\Research_Projects\crystal_generation_project\MatGraphDB\data\production\materials_project\graph_database\main\nodes\CHEMENV.parquet
# 1 Z:\Research_Projects\crystal_generation_project\MatGraphDB\data\production\materials_project\graph_database\main\nodes\CRYSTAL_SYSTEM.parquet
# 2 Z:\Research_Projects\crystal_generation_project\MatGraphDB\data\production\materials_project\graph_database\main\nodes\ELEMENT.parquet
# 3 Z:\Research_Projects\crystal_generation_project\MatGraphDB\data\production\materials_project\graph_database\main\nodes\LATTICE.parquet
# 4 Z:\Research_Projects\crystal_generation_project\MatGraphDB\data\production\materials_project\graph_database\main\nodes\MAGNETIC_STATE.parquet
# 5 Z:\Research_Projects\crystal_generation_project\MatGraphDB\data\production\materials_project\graph_database\main\nodes\MATERIAL.parquet
# 6 Z:\Research_Projects\crystal_generation_project\MatGraphDB\data\production\materials_project\graph_database\main\nodes\OXIDATION_STATE.parquet
# 7 Z:\Research_Projects\crystal_generation_project\MatGraphDB\data\production\materials_project\graph_database\main\nodes\SITE.parquet
# 8 Z:\Research_Projects\crystal_generation_project\MatGraphDB\data\production\materials_project\graph_database\main\nodes\SPACE_GROUP.parquet
# 9 Z:\Research_Projects\crystal_generation_project\MatGraphDB\data\production\materials_project\graph_database\main\nodes\SPG_WYCKOFF.parquet
# ----------------------------------------------------------------------------------------------------
# Relationships
# ----------------------------------------------------------------------------------------------------
# 0 Z:\Research_Projects\crystal_generation_project\MatGraphDB\data\production\materials_project\graph_database\main\relationships\CHEMENV-ELECTRIC_CONNECTS-CHEMENV.parquet
# 1 Z:\Research_Projects\crystal_generation_project\MatGraphDB\data\production\materials_project\graph_database\main\relationships\CHEMENV-GEOMETRIC_CONNECTS-CHEMENV.parquet
# 2 Z:\Research_Projects\crystal_generation_project\MatGraphDB\data\production\materials_project\graph_database\main\relationships\CHEMENV-GEOMETRIC_ELECTRIC_CONNECTS-CHEMENV.parquet
# 3 Z:\Research_Projects\crystal_generation_project\MatGraphDB\data\production\materials_project\graph_database\main\relationships\ELEMENT-CAN_OCCUR-CHEMENV.parquet
# 4 Z:\Research_Projects\crystal_generation_project\MatGraphDB\data\production\materials_project\graph_database\main\relationships\ELEMENT-CAN_OCCUR-OXIDATION_STATE.parquet
# 5 Z:\Research_Projects\crystal_generation_project\MatGraphDB\data\production\materials_project\graph_database\main\relationships\ELEMENT-ELECTRIC_CONNECTS-ELEMENT.parquet
# 6 Z:\Research_Projects\crystal_generation_project\MatGraphDB\data\production\materials_project\graph_database\main\relationships\ELEMENT-GEOMETRIC_CONNECTS-ELEMENT.parquet
# 7 Z:\Research_Projects\crystal_generation_project\MatGraphDB\data\production\materials_project\graph_database\main\relationships\ELEMENT-GEOMETRIC_ELECTRIC_CONNECTS-ELEMENT.parquet
# 8 Z:\Research_Projects\crystal_generation_project\MatGraphDB\data\production\materials_project\graph_database\main\relationships\ELEMENT-GROUP_PERIOD_CONNECTS-ELEMENT.parquet
# 9 Z:\Research_Projects\crystal_generation_project\MatGraphDB\data\production\materials_project\graph_database\main\relationships\MATERIAL-HAS-CHEMENV.parquet
# 10 Z:\Research_Projects\crystal_generation_project\MatGraphDB\data\production\materials_project\graph_database\main\relationships\MATERIAL-HAS-CRYSTAL_SYSTEM.parquet
# 11 Z:\Research_Projects\crystal_generation_project\MatGraphDB\data\production\materials_project\graph_database\main\relationships\MATERIAL-HAS-ELEMENT.parquet
# 12 Z:\Research_Projects\crystal_generation_project\MatGraphDB\data\production\materials_project\graph_database\main\relationships\MATERIAL-HAS-LATTICE.parquet
# 13 Z:\Research_Projects\crystal_generation_project\MatGraphDB\data\production\materials_project\graph_database\main\relationships\MATERIAL-HAS-SITE.parquet
# 14 Z:\Research_Projects\crystal_generation_project\MatGraphDB\data\production\materials_project\graph_database\main\relationships\MATERIAL-HAS-SPACE_GROUP.parquet
# ----------------------------------------------------------------------------------------------------

# %% [markdown]
# ## Defining the node and relationship properties

# %%
node_properties={
        'CHEMENV':[
            'coordination',
        ],
        'ELEMENT':[
            'abundance_universe',
            'abundance_solar',
            'abundance_meteor',
            'abundance_crust',
            'abundance_ocean',
            'abundance_human',
            'atomic_mass',
            'atomic_number',
            'block',
            'boiling_point',
            'critical_pressure',
            'critical_temperature',
            'density_stp',
            'electron_affinity',
            'electronegativity_pauling',
            'extended_group',
            'heat_specific',
            'heat_vaporization',
            'heat_fusion',
            'heat_molar',
            'magnetic_susceptibility_mass',
            'magnetic_susceptibility_molar',
            'magnetic_susceptibility_volume',
            'melting_point',
            'molar_volume',
            'neutron_cross_section',
            'neutron_mass_absorption',
            'period',
            'radius_calculated',
            'radius_empirical',
            'radius_covalent',
            'radius_vanderwaals',
            'refractive_index',
            'speed_of_sound',
            'conductivity_electric',
            'electrical_resistivity',
            'modulus_bulk',
            'modulus_shear',
            'modulus_young',
            'poisson_ratio',
            'coefficient_of_linear_thermal_expansion',
            'hardness_vickers',
            'hardness_brinell',
            'hardness_mohs',
            'superconduction_temperature',
            'is_actinoid',
            'is_alkali',
            'is_alkaline',
            'is_chalcogen',
            'is_halogen',
            'is_lanthanoid',
            'is_metal',
            'is_metalloid',
            'is_noble_gas',
            'is_post_transition_metal',
            'is_quadrupolar',
            'is_rare_earth_metal',
            'experimental_oxidation_states',
        ],
        'MATERIAL':[
            'nsites',
            'nelements',
            'volume',
            'density',
            'density_atomic',
            'crystal_system',
            'a',
            'b',
            'c',
            'alpha',
            'beta',
            'gamma',
            'unit_cell_volume',
            # 'energy_per_atom',
            # 'formation_energy_per_atom',
            # 'energy_above_hull',
            # 'band_gap',
            # 'cbm',
            # 'vbm',
            # 'efermi',
            # 'is_stable',
            # 'is_gap_direct',
            # 'is_metal',
            # 'is_magnetic',
            # 'ordering',
            # 'total_magnetization',
            # 'total_magnetization_normalized_vol',
            # 'num_magnetic_sites',
            # 'num_unique_magnetic_sites',
            # 'e_total',
            # 'e_ionic',
            # 'e_electronic',
            # 'sine_coulomb_matrix',
            # 'element_fraction',
            # 'element_property',
            # 'xrd_pattern',
            # 'uncorrected_energy_per_atom',
            # 'equilibrium_reaction_energy_per_atom',
            # 'n',
            # 'e_ij_max',
            # 'weighted_surface_energy_EV_PER_ANG2',
            # 'weighted_surface_energy',
            # 'weighted_work_function',
            # 'surface_anisotropy',
            # 'shape_factor',
            # 'elasticity-k_vrh',
            'elasticity-k_reuss',
            'elasticity-k_voigt',
            'elasticity-g_vrh',
            'elasticity-g_reuss',
            'elasticity-g_voigt',
            'elasticity-sound_velocity_transverse',
            'elasticity-sound_velocity_longitudinal',
            'elasticity-sound_velocity_total',
            'elasticity-sound_velocity_acoustic',
            'elasticity-sound_velocity_optical',
            # 'elasticity-thermal_conductivity_clarke',
            # 'elasticity-thermal_conductivity_cahill',
            # 'elasticity-young_modulus',
            # 'elasticity-universal_anisotropy',
            # 'elasticity-homogeneous_poisson',
            # 'elasticity-debye_temperature',
            # 'elasticity-state',
        ]
    }


relationship_properties={
    'ELEMENT-CAN_OCCUR-CHEMENV':[
        'weight',
        ],
    'ELEMENT-GEOMETRIC_ELECTRIC_CONNECTS-ELEMENT':[
        'weight',
        ],
    'CHEMENV-GEOMETRIC_ELECTRIC_CONNECTS-CHEMENV':[
         'weight',
      ],
    'MATERIAL-HAS-CHEMENV':[
         'weight',
    ],
    'MATERIAL-HAS-ELEMENT':[
        'weight',
    ],
}

# %% [markdown]
# ## Adding node and relationship properties to the data generator

# %%
generator.add_node_type(node_path='Z:/Research_Projects/crystal_generation_project/MatGraphDB/data/production/materials_project/graph_database/main/nodes/CHEMENV.parquet',
                        feature_columns=node_properties['CHEMENV'],
                        target_columns=[])
generator.add_node_type(node_path='Z:/Research_Projects/crystal_generation_project/MatGraphDB/data/production/materials_project/graph_database/main/nodes/ELEMENT.parquet',
                        feature_columns=node_properties['ELEMENT'],
                        target_columns=[])
generator.add_node_type(node_path='Z:/Research_Projects/crystal_generation_project/MatGraphDB/data/production/materials_project/graph_database/main/nodes/MATERIAL.parquet',
                        feature_columns=node_properties['MATERIAL'],
                        target_columns=['elasticity-k_vrh'])
print(generator.hetero_data)
# Out:
# HeteroData(
#   CHEMENV={
#     node_id=[61],
#     names=[61],
#     x=[61, 14],
#     feature_names=[14],
#   },
#   ELEMENT={
#     node_id=[118],
#     names=[118],
#     x=[118, 299],
#     feature_names=[299],
#   },
#   MATERIAL={
#     node_id=[10169],
#     names=[10169],
#     x=[10169, 29],
#     feature_names=[29],
#     y_label_name=[1],
#     out_channels=1,
#     y=[10169, 1],
#     y_names=[1],
#   }
# )

# %%
generator.add_edge_type(edge_path='Z:/Research_Projects/crystal_generation_project/MatGraphDB/data/production/materials_project/graph_database/main/relationships/CHEMENV-GEOMETRIC_ELECTRIC_CONNECTS-CHEMENV.parquet',
                        feature_columns=relationship_properties['CHEMENV-GEOMETRIC_ELECTRIC_CONNECTS-CHEMENV'],
                        # target_columns=['weight'],
                        # custom_encoders={}, 
                        # node_filter={},
                        undirected=True)

generator.add_edge_type(edge_path='Z:/Research_Projects/crystal_generation_project/MatGraphDB/data/production/materials_project/graph_database/main/relationships/ELEMENT-GEOMETRIC_ELECTRIC_CONNECTS-ELEMENT.parquet',
                        feature_columns=relationship_properties['ELEMENT-GEOMETRIC_ELECTRIC_CONNECTS-ELEMENT'],
                        # target_columns=['weight'],
                        # custom_encoders={}, 
                        # node_filter={},
                        undirected=True)

generator.add_edge_type(edge_path='Z:/Research_Projects/crystal_generation_project/MatGraphDB/data/production/materials_project/graph_database/main/relationships/MATERIAL-HAS-CHEMENV.parquet',
                        feature_columns=relationship_properties['MATERIAL-HAS-CHEMENV'],
                        # target_columns=['weight'],
                        # custom_encoders={}, 
                        # node_filter={},
                        undirected=True)

generator.add_edge_type(edge_path='Z:/Research_Projects/crystal_generation_project/MatGraphDB/data/production/materials_project/graph_database/main/relationships/MATERIAL-HAS-ELEMENT.parquet',
                        feature_columns=relationship_properties['MATERIAL-HAS-ELEMENT'],
                        # target_columns=['weight'],
                        # custom_encoders={}, 
                        # node_filter={},
                        undirected=True)

generator.add_edge_type(edge_path='Z:/Research_Projects/crystal_generation_project/MatGraphDB/data/production/materials_project/graph_database/main/relationships/ELEMENT-CAN_OCCUR-CHEMENV.parquet',
                        feature_columns=relationship_properties['ELEMENT-CAN_OCCUR-CHEMENV'],
                        # target_columns=['weight'],
                        # custom_encoders={}, 
                        # node_filter={},
                        undirected=True)
print(generator.hetero_data)
# Out:
# HeteroData(
#   CHEMENV={
#     node_id=[61],
#     names=[61],
#     x=[61, 14],
#     feature_names=[14],
#   },
#   ELEMENT={
#     node_id=[118],
#     names=[118],
#     x=[118, 299],
#     feature_names=[299],
#   },
#   MATERIAL={
#     node_id=[10169],
#     names=[10169],
#     x=[10169, 29],
#     feature_names=[29],
#     y_label_name=[1],
#     out_channels=1,
#     y=[10169, 1],
#     y_names=[1],
#   },
#   (CHEMENV, GEOMETRIC_ELECTRIC_CONNECTS, CHEMENV)={
#     edge_index=[2, 1410],
#     edge_attr=[1410, 1],
#     property_names=[1],
#   },
#   (CHEMENV, rev_GEOMETRIC_ELECTRIC_CONNECTS, CHEMENV)={
#     edge_index=[2, 1410],
#     edge_attr=[1410, 1],
#   },
#   (ELEMENT, GEOMETRIC_ELECTRIC_CONNECTS, ELEMENT)={
#     edge_index=[2, 2683],
#     edge_attr=[2683, 1],
#     property_names=[1],
#   },
#   (ELEMENT, rev_GEOMETRIC_ELECTRIC_CONNECTS, ELEMENT)={
#     edge_index=[2, 2683],
#     edge_attr=[2683, 1],
#   },
#   (MATERIAL, HAS, CHEMENV)={
#     edge_index=[2, 22156],
#     edge_attr=[22156, 1],
#     property_names=[1],
#   },
#   (CHEMENV, rev_HAS, MATERIAL)={
#     edge_index=[2, 22156],
#     edge_attr=[22156, 1],
#   },
#   (MATERIAL, HAS, ELEMENT)={
#     edge_index=[2, 26722],
#     edge_attr=[26722, 1],
#     property_names=[1],
#   },
#   (ELEMENT, rev_HAS, MATERIAL)={
#     edge_index=[2, 26722],
#     edge_attr=[26722, 1],
#   },
#   (ELEMENT, CAN_OCCUR, CHEMENV)={
#     edge_index=[2, 3043],
#     edge_attr=[3043, 1],
#     property_names=[1],
#   },
#   (CHEMENV, rev_CAN_OCCUR, ELEMENT)={
#     edge_index=[2, 3043],
#     edge_attr=[3043, 1],
#   }
# )

# %%
print(dir(generator.hetero_data))

print(generator.hetero_data.edge_types)

print(generator.hetero_data.metadata())
# Out:
# ['__annotations__', '__cat_dim__', '__class__', '__contains__', '__copy__', '__deepcopy__', '__delattr__', '__delitem__', '__dict__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattr__', '__getattribute__', '__getitem__', '__getstate__', '__gt__', '__hash__', '__inc__', '__init__', '__init_subclass__', '__iter__', '__le__', '__len__', '__lt__', '__module__', '__ne__', '__new__', '__reduce__', '__reduce_ex__', '__repr__', '__setattr__', '__setitem__', '__setstate__', '__sizeof__', '__str__', '__subclasshook__', '__weakref__', '_check_type_name', '_edge_attr_cls', '_edge_store_dict', '_edge_to_layout', '_edges_to_layout', '_get_edge_index', '_get_tensor', '_get_tensor_size', '_global_store', '_multi_get_tensor', '_node_store_dict', '_put_edge_index', '_put_tensor', '_remove_edge_index', '_remove_tensor', '_tensor_attr_cls', '_to_canonical', '_to_type', 'apply', 'apply_', 'clone', 'coalesce', 'collect', 'concat', 'contains_isolated_nodes', 'contains_self_loops', 'contiguous', 'coo', 'cpu', 'csc', 'csr', 'cuda', 'debug', 'detach', 'detach_', 'edge_attrs', 'edge_items', 'edge_stores', 'edge_subgraph', 'edge_type_subgraph', 'edge_types', 'from_dict', 'generate_ids', 'get_all_edge_attrs', 'get_all_tensor_attrs', 'get_edge_index', 'get_edge_store', 'get_node_store', 'get_tensor', 'get_tensor_size', 'has_isolated_nodes', 'has_self_loops', 'is_coalesced', 'is_cuda', 'is_directed', 'is_sorted', 'is_sorted_by_time', 'is_undirected', 'keys', 'metadata', 'multi_get_tensor', 'node_attrs', 'node_items', 'node_offsets', 'node_stores', 'node_type_subgraph', 'node_types', 'num_edge_features', 'num_edges', 'num_features', 'num_node_features', 'num_nodes', 'pin_memory', 'put_edge_index', 'put_tensor', 'record_stream', 'remove_edge_index', 'remove_tensor', 'rename', 'requires_grad_', 'set_value_dict', 'share_memory_', 'size', 'snapshot', 'sort', 'sort_by_time', 'stores', 'stores_as', 'subgraph', 'to', 'to_dict', 'to_homogeneous', 'to_namedtuple', 'up_to', 'update', 'update_tensor', 'validate', 'view']
# [('CHEMENV', 'GEOMETRIC_ELECTRIC_CONNECTS', 'CHEMENV'), ('CHEMENV', 'rev_GEOMETRIC_ELECTRIC_CONNECTS', 'CHEMENV'), ('ELEMENT', 'GEOMETRIC_ELECTRIC_CONNECTS', 'ELEMENT'), ('ELEMENT', 'rev_GEOMETRIC_ELECTRIC_CONNECTS', 'ELEMENT'), ('MATERIAL', 'HAS', 'CHEMENV'), ('CHEMENV', 'rev_HAS', 'MATERIAL'), ('MATERIAL', 'HAS', 'ELEMENT'), ('ELEMENT', 'rev_HAS', 'MATERIAL'), ('ELEMENT', 'CAN_OCCUR', 'CHEMENV'), ('CHEMENV', 'rev_CAN_OCCUR', 'ELEMENT')]
# (['CHEMENV', 'ELEMENT', 'MATERIAL'], [('CHEMENV', 'GEOMETRIC_ELECTRIC_CONNECTS', 'CHEMENV'), ('CHEMENV', 'rev_GEOMETRIC_ELECTRIC_CONNECTS', 'CHEMENV'), ('ELEMENT', 'GEOMETRIC_ELECTRIC_CONNECTS', 'ELEMENT'), ('ELEMENT', 'rev_GEOMETRIC_ELECTRIC_CONNECTS', 'ELEMENT'), ('MATERIAL', 'HAS', 'CHEMENV'), ('CHEMENV', 'rev_HAS', 'MATERIAL'), ('MATERIAL', 'HAS', 'ELEMENT'), ('ELEMENT', 'rev_HAS', 'MATERIAL'), ('ELEMENT', 'CAN_OCCUR', 'CHEMENV'), ('CHEMENV', 'rev_CAN_OCCUR', 'ELEMENT')])

# %% [markdown]
# ## Defining the model

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
from torch_geometric.loader import NeighborLoader
from torch_geometric.nn import  SAGEConv, GCNConv, GraphConv, to_hetero, GraphSAGE

from matgraphdb.graph_kit.pyg.metrics import ClassificationMetrics,RegressionMetrics

# %%
class HeteroInputLayer(nn.Module):
    def __init__(self, data, n_embd:int, 
                device='cuda:0'):
        super().__init__()

        self.embs = nn.ModuleDict()
        self.data_lins = nn.ModuleDict()

        for node_type in data.node_types:
            num_nodes = data[node_type].num_nodes
            num_features = data[node_type].num_node_features
            self.embs[node_type]=nn.Embedding(num_nodes,n_embd,device=device)
            if num_features != 0:
                self.data_lins[node_type]=nn.Linear(num_features, n_embd,device=device)

    def forward(self, data):
        x_dict={}
        edge_index_dict={}
        edge_attr_dict={}
        for node_type, emb_layer in self.embs.items():
            # Handling nodes based on feature availability
            if node_type in self.data_lins:
                x_dict[node_type] = self.data_lins[node_type](data[node_type].x) + emb_layer(data[node_type].node_id)
            else:
                x_dict[node_type] = emb_layer(data[node_type].node_id)

            # edge_index_dict[node_type] = data[node_type].edge_index
            # edge_attr_dict[node_type] = data[node_type].edge_attr

        return x_dict

# %% [markdown]
# ## Training

# %%
class FeedFoward(nn.Module):
    """ a simple linear layer followed by a non-linearity """

    def __init__(self, n_embd, dropout=0.0):
        super().__init__()

        self.net = nn.Sequential(
            nn.Linear(n_embd, 4 * n_embd),
            nn.ReLU(),
            nn.Linear(4 * n_embd, n_embd),
            nn.Dropout(dropout),
        )
        self.ln=nn.LayerNorm(n_embd)

    def forward(self, x):
        return self.net(self.ln(x))


class HeteroConvModel(nn.Module):
    def __init__(self, data, n_embd:int, 
                out_channels:int,
                prediction_node_type:str,
                n_conv_layers=1,
                aggr='sum',
                dropout=0.0,
                conv_params={
                    'dropout': 0.0,
                    'act': 'relu',
                    'act_first': True},
                device='cuda:0'):
        super(HeteroConvModel, self).__init__()
        self.prediction_node_type=prediction_node_type
        self.input_layer=HeteroInputLayer(data, n_embd, device=device)

        self.fwd1_dict = nn.ModuleDict()
        for node_type in data.node_types:
           self.fwd1_dict[node_type]=FeedFoward(n_embd, dropout=dropout)

        # Initialize and convert GraphSAGE to heterogeneous
        self.graph_conv=GraphSAGE( n_embd, n_embd, n_conv_layers, **conv_params)
        self.stacked_conv = to_hetero(self.graph_conv, metadata=data.metadata())

        self.fwd2_dict = nn.ModuleDict()
        for node_type in data.node_types:
           self.fwd2_dict[node_type]=FeedFoward(n_embd, dropout=dropout)

        self.output_layer = nn.Linear(n_embd, out_channels)

    def forward(self, data):
        x_dict = self.input_layer(data)
        for node_type in data.node_types:
            x_dict[node_type]=self.fwd1_dict[node_type](x_dict[node_type])
        x_dict=self.stacked_conv(x_dict, data.edge_index_dict)
        for node_type in data.node_types:
            x_dict[node_type]=self.fwd2_dict[node_type](x_dict[node_type])

        out=self.output_layer(x_dict[self.prediction_node_type])
        return out

# %%
NODE_TYPE='MATERIAL'
def split_data_on_node_type(data,node_type,train_proportion=0.8,test_proportion=0.1, val_proportion=0.1):
    assert train_proportion + test_proportion + val_proportion == 1.0
    for node_type in data.node_types:
        train_mask=torch.zeros(data[node_type].num_nodes,dtype=torch.bool)
        test_mask=torch.zeros(data[node_type].num_nodes,dtype=torch.bool)
        val_mask=torch.zeros(data[node_type].num_nodes,dtype=torch.bool)

        num_nodes_for_type=data[node_type].num_nodes
        if node_type==NODE_TYPE:
            # Determine indices for training, testing, and validation
            indices = torch.randperm(num_nodes_for_type)

            num_train = int(train_proportion * num_nodes_for_type)
            num_val = int(test_proportion * num_nodes_for_type)
            num_test = num_nodes_for_type - num_train - num_val

            train_mask[indices[:num_train]] = True
            val_mask[indices[num_train:num_train + num_val]] = True
            test_mask[indices[num_train + num_val:]] = True
        else:
            train_mask[:num_nodes_for_type]=True

        data[node_type].train_mask=train_mask
        data[node_type].test_mask=test_mask
        data[node_type].val_mask=val_mask
    return data


# Training params
TRAIN_PROPORTION = 0.8
TEST_PROPORTION = 0.1
VAL_PROPORTION = 0.1
LEARNING_RATE = 0.001
N_EPCOHS = 1000

N_EMBD=128
OUT_CHANNELS = 1
NUM_LAYERS=1
EVAL_INTERVAL = 10

hetero_data=generator.hetero_data




device =  "cuda:0" if torch.cuda.is_available() else torch.device("cpu")
hetero_data=split_data_on_node_type(hetero_data,
                            node_type=NODE_TYPE,
                            train_proportion=TRAIN_PROPORTION,
                            test_proportion=TEST_PROPORTION,
                            val_proportion=VAL_PROPORTION)

print(hetero_data)
print(hetero_data[NODE_TYPE].train_mask)
print(hetero_data[NODE_TYPE].test_mask)
print(hetero_data[NODE_TYPE].val_mask)

model=HeteroConvModel(hetero_data, 
                n_embd=N_EMBD, 
                out_channels=OUT_CHANNELS,
                prediction_node_type=NODE_TYPE,
                n_conv_layers=NUM_LAYERS,
                aggr='add',
                conv_params={
                    'dropout': 0.0,
                    'act': 'relu',
                    'act_first': True},
                device=device)
model.to(device)


optimizer = torch.optim.Adam(model.parameters(), lr=LEARNING_RATE)
if OUT_CHANNELS==1:
    loss_fn=nn.MSELoss()
else:
    loss_fn=nn.CrossEntropyLoss()
# Out:
# HeteroData(
#   CHEMENV={
#     node_id=[61],
#     names=[61],
#     x=[61, 14],
#     feature_names=[14],
#     train_mask=[61],
#     test_mask=[61],
#     val_mask=[61],
#   },
#   ELEMENT={
#     node_id=[118],
#     names=[118],
#     x=[118, 299],
#     feature_names=[299],
#     train_mask=[118],
#     test_mask=[118],
#     val_mask=[118],
#   },
#   MATERIAL={
#     node_id=[10169],
#     names=[10169],
#     x=[10169, 29],
#     feature_names=[29],
#     y_label_name=[1],
#     out_channels=1,
#     y=[10169, 1],
#     y_names=[1],
#     train_mask=[10169],
#     test_mask=[10169],
#     val_mask=[10169],
#   },
#   (CHEMENV, GEOMETRIC_ELECTRIC_CONNECTS, CHEMENV)={
#     edge_index=[2, 1410],
#     edge_attr=[1410, 1],
#     property_names=[1],
#   },
#   (CHEMENV, rev_GEOMETRIC_ELECTRIC_CONNECTS, CHEMENV)={
#     edge_index=[2, 1410],
#     edge_attr=[1410, 1],
#   },
#   (ELEMENT, GEOMETRIC_ELECTRIC_CONNECTS, ELEMENT)={
#     edge_index=[2, 2683],
#     edge_attr=[2683, 1],
#     property_names=[1],
#   },
#   (ELEMENT, rev_GEOMETRIC_ELECTRIC_CONNECTS, ELEMENT)={
#     edge_index=[2, 2683],
#     edge_attr=[2683, 1],
#   },
#   (MATERIAL, HAS, CHEMENV)={
#     edge_index=[2, 22156],
#     edge_attr=[22156, 1],
#     property_names=[1],
#   },
#   (CHEMENV, rev_HAS, MATERIAL)={
#     edge_index=[2, 22156],
#     edge_attr=[22156, 1],
#   },
#   (MATERIAL, HAS, ELEMENT)={
#     edge_index=[2, 26722],
#     edge_attr=[26722, 1],
#     property_names=[1],
#   },
#   (ELEMENT, rev_HAS, MATERIAL)={
#     edge_index=[2, 26722],
#     edge_attr=[26722, 1],
#   },
#   (ELEMENT, CAN_OCCUR, CHEMENV)={
#     edge_index=[2, 3043],
#     edge_attr=[3043, 1],
#     property_names=[1],
#   },
#   (CHEMENV, rev_CAN_OCCUR, ELEMENT)={
#     edge_index=[2, 3043],
#     edge_attr=[3043, 1],
#   }
# )
# tensor([True, True, True,  ..., True, True, True])
# tensor([False, False, False,  ..., False, False, False])
# tensor([False, False, False,  ..., False, False, False])

# %%
def train(model, optimizer, data, loss_fn):
    model.train()
    total_loss = 0
    total_examples = 0

    data = data.to(device)
    optimizer.zero_grad()

    out = model(data)
    mask=data[NODE_TYPE].train_mask
    pred=out[mask]
    ground_truth=data[NODE_TYPE].y[mask]

    loss = loss_fn(pred, ground_truth)

    loss.backward()
    optimizer.step()
    total_loss += float(loss)
    total_examples += pred.numel()

    return total_loss 


def evaluate(model, data):
    model.eval()
    with torch.no_grad():
        
        losses=[]
        metrics={"val":{},"test":{}}
        data = data.to(device)
        optimizer.zero_grad()

        logits = model(data)
        out_channel=logits.shape[1]
        for key in metrics.keys():
            if out_channel==1:
                metrics[key]['mape']=[]
                metrics[key]['mae']=[]
            else:
                metrics[key]['accuracy']=[]
                metrics[key]['precision']=[]
                metrics[key]['recall']=[]
                metrics[key]['f1']=[]

        for split in ['val_mask', 'test_mask']:
            mask=data[NODE_TYPE][split]
            masked_logits=logits[mask]
            ground_truth=data[NODE_TYPE].y[mask]

            loss = loss_fn(masked_logits, ground_truth)

            out_channel=logits.shape[1]
            split_name=split.split('_')[0]
            if out_channel==1:
                mape=RegressionMetrics.mean_absolute_percentage_error(y_pred=masked_logits,y_true=ground_truth)
                mae=RegressionMetrics.mean_absolute_error(y_pred=masked_logits,y_true=ground_truth)
                metrics[split_name]['mape'].append(mape.item())
                metrics[split_name]['mae'].append(mae.item())
            else:
                probabilities = torch.sigmoid(masked_logits)
                # Converting masked_logits from (batch_size, out_channels) to (batch_size,)
                pred=probabilities.argmax(1)

                
                # accuracy=ClassificationMetrics.accuracy(y_pred=pred,y_true=ground_truth)
                # metrics[split_name]['accuracy'].append(accuracy.item()*100)

                cm=ClassificationMetrics.confusion_matrix(y_pred=pred,y_true=ground_truth,num_classes=out_channel)

                weights=cm.sum(dim=1)/cm.sum(dim=1).sum()

                accuracy=ClassificationMetrics.multi_class_accuracy(confusion_matrix=cm)
                avg_accuracy=(weights * accuracy).sum()
                metrics[split_name]['accuracy'].append(avg_accuracy*100)

                precision=ClassificationMetrics.multiclass_precision(confusion_matrix=cm)
                avg_precision= (weights * precision).sum()
                metrics[split_name]['precision'].append(avg_precision*100)

                recall=ClassificationMetrics.multiclass_recall(confusion_matrix=cm)
                avg_recall=(weights * recall).sum()
                metrics[split_name]['recall'].append(avg_recall*100)

                f1=ClassificationMetrics.multiclass_f1_score(confusion_matrix=cm)
                avg_f1=(weights * f1).sum()
                metrics[split_name]['f1'].append(avg_f1*100)

            losses.append(loss.item())

    return losses,metrics

# %%
for epoch in range(N_EPCOHS):
    train_loss = train(model, optimizer, hetero_data, loss_fn=loss_fn)
    if epoch%EVAL_INTERVAL==0:
        losses,metrics = evaluate(model, hetero_data)

        # print(f"Epoch: {epoch:03d},Train Loss: {train_loss:.4f}, Val Loss: {losses[0]:.4f}, Test Loss: {losses[1]:.4f}")

        metrics_str=""
        metrics_str+=f"Epoch: {epoch:03d},Train Loss: {train_loss:.4f}, Test Loss: {losses[1]:.4f}"
        for split,metrics_dict in metrics.items():
            metrics_str+=" | "
            for i,(key,value) in enumerate(metrics_dict.items()):
                if i==0:
                    metrics_str+=f" {split}-{key}: {value[0]:.2f}"
                else:
                    metrics_str+=f", {split}-{key}: {value[0]:.2f}"
        print(metrics_str)
# Out:
# Epoch: 000,Train Loss: 948466024448.0000, Test Loss: 4319684591616.0000 |  val-mape: 97.19, val-mae: 1414.10 |  test-mape: 96.70, test-mae: 65421.35
# Epoch: 010,Train Loss: 948465303552.0000, Test Loss: 4319680397312.0000 |  val-mape: 80.66, val-mae: 1389.08 |  test-mape: 99.67, test-mae: 65397.42
# Epoch: 020,Train Loss: 948462157824.0000, Test Loss: 4319665979392.0000 |  val-mape: 254.12, val-mae: 1385.52 |  test-mape: 364.39, test-mae: 65399.99
# Epoch: 030,Train Loss: 948454227968.0000, Test Loss: 4319626133504.0000 |  val-mape: 915.78, val-mae: 1638.01 |  test-mape: 1249.83, test-mae: 65657.12
# Epoch: 040,Train Loss: 948436140032.0000, Test Loss: 4319541460992.0000 |  val-mape: 87.45, val-mae: 1401.28 |  test-mape: 91.27, test-mae: 65411.12
# Epoch: 050,Train Loss: 948401733632.0000, Test Loss: 4319379456000.0000 |  val-mape: 85.16, val-mae: 1390.00 |  test-mape: 92.98, test-mae: 65403.93
# Epoch: 060,Train Loss: 948341637120.0000, Test Loss: 4319100534784.0000 |  val-mape: 179.40, val-mae: 1358.59 |  test-mape: 249.89, test-mae: 65383.07
# Epoch: 070,Train Loss: 948244971520.0000, Test Loss: 4318653579264.0000 |  val-mape: 236.69, val-mae: 1356.13 |  test-mape: 322.58, test-mae: 65391.36
# Epoch: 080,Train Loss: 948097974272.0000, Test Loss: 4317976723456.0000 |  val-mape: 184.71, val-mae: 1337.63 |  test-mape: 234.01, test-mae: 65381.19
# Epoch: 090,Train Loss: 947884785664.0000, Test Loss: 4316998402048.0000 |  val-mape: 230.28, val-mae: 1318.41 |  test-mape: 284.76, test-mae: 65384.27
# Epoch: 100,Train Loss: 947586793472.0000, Test Loss: 4315634204672.0000 |  val-mape: 252.15, val-mae: 1314.73 |  test-mape: 297.67, test-mae: 65384.11
# Epoch: 110,Train Loss: 947183812608.0000, Test Loss: 4313789759488.0000 |  val-mape: 281.01, val-mae: 1321.68 |  test-mape: 308.53, test-mae: 65383.31
# Epoch: 120,Train Loss: 946652971008.0000, Test Loss: 4311361781760.0000 |  val-mape: 333.61, val-mae: 1321.22 |  test-mape: 343.89, test-mae: 65384.25
# Epoch: 130,Train Loss: 945969954816.0000, Test Loss: 4308235190272.0000 |  val-mape: 387.91, val-mae: 1258.52 |  test-mape: 370.44, test-mae: 65383.79
# Epoch: 140,Train Loss: 945107304448.0000, Test Loss: 4304284418048.0000 |  val-mape: 473.49, val-mae: 1256.78 |  test-mape: 427.76, test-mae: 65385.25
# Epoch: 150,Train Loss: 944038477824.0000, Test Loss: 4299379965952.0000 |  val-mape: 561.96, val-mae: 1218.54 |  test-mape: 476.03, test-mae: 65385.06
# Epoch: 160,Train Loss: 942738112512.0000, Test Loss: 4293392596992.0000 |  val-mape: 676.76, val-mae: 1172.33 |  test-mape: 544.93, test-mae: 65410.56
# Epoch: 170,Train Loss: 941168263168.0000, Test Loss: 4286141431808.0000 |  val-mape: 359.77, val-mae: 928.26 |  test-mape: 603.93, test-mae: 65476.06
# Epoch: 180,Train Loss: 939307433984.0000, Test Loss: 4277548613632.0000 |  val-mape: 992.34, val-mae: 1052.81 |  test-mape: 722.44, test-mae: 65639.38
# Epoch: 190,Train Loss: 937128820736.0000, Test Loss: 4267338104832.0000 |  val-mape: 1174.97, val-mae: 973.24 |  test-mape: 703.94, test-mae: 65685.51
# Epoch: 200,Train Loss: 934606012416.0000, Test Loss: 4255399542784.0000 |  val-mape: 1406.52, val-mae: 887.63 |  test-mape: 664.96, test-mae: 65681.09
# Epoch: 210,Train Loss: 931710894080.0000, Test Loss: 4241582194688.0000 |  val-mape: 1675.59, val-mae: 837.72 |  test-mape: 486.12, test-mae: 65532.63
# Epoch: 220,Train Loss: 928436649984.0000, Test Loss: 4225886322688.0000 |  val-mape: 1793.16, val-mae: 897.49 |  test-mape: 554.06, test-mae: 65676.52
# Epoch: 230,Train Loss: 924749463552.0000, Test Loss: 4208032219136.0000 |  val-mape: 1454.23, val-mae: 1013.95 |  test-mape: 928.86, test-mae: 65923.55
# Epoch: 240,Train Loss: 920543035392.0000, Test Loss: 4187537276928.0000 |  val-mape: 1774.43, val-mae: 1292.74 |  test-mape: 624.46, test-mae: 65705.47
# Epoch: 250,Train Loss: 915817627648.0000, Test Loss: 4164656300032.0000 |  val-mape: 2454.70, val-mae: 1827.93 |  test-mape: 834.43, test-mae: 65628.76
# Epoch: 260,Train Loss: 910580187136.0000, Test Loss: 4138736025600.0000 |  val-mape: 1127.34, val-mae: 1561.99 |  test-mape: 759.15, test-mae: 65589.20
# Epoch: 270,Train Loss: 904778874880.0000, Test Loss: 4109945536512.0000 |  val-mape: 1635.20, val-mae: 1525.06 |  test-mape: 855.33, test-mae: 65499.55
# Epoch: 280,Train Loss: 898536701952.0000, Test Loss: 4078264647680.0000 |  val-mape: 1220.97, val-mae: 1192.17 |  test-mape: 1196.03, test-mae: 65534.34
# Epoch: 290,Train Loss: 891426897920.0000, Test Loss: 4043493867520.0000 |  val-mape: 1359.78, val-mae: 1034.09 |  test-mape: 914.04, test-mae: 65432.10
# Epoch: 300,Train Loss: 883852771328.0000, Test Loss: 4005592563712.0000 |  val-mape: 1288.21, val-mae: 716.78 |  test-mape: 1045.95, test-mae: 65388.39
# Epoch: 310,Train Loss: 875717132288.0000, Test Loss: 3964320350208.0000 |  val-mape: 2094.57, val-mae: 1197.29 |  test-mape: 1631.70, test-mae: 65497.39
# Epoch: 320,Train Loss: 866445688832.0000, Test Loss: 3968393805824.0000 |  val-mape: 1076.98, val-mae: 745.24 |  test-mape: 1352.60, test-mae: 65779.80
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[29], line 2
#       1 for epoch in range(N_EPCOHS):
# ----> 2     train_loss = train(model, optimizer, hetero_data, loss_fn=loss_fn)
#       3     if epoch%EVAL_INTERVAL==0:
#       4         losses,metrics = evaluate(model, hetero_data)
#
# Cell In[28], line 6, in train(model, optimizer, data, loss_fn)
#       3 total_loss = 0
#       4 total_examples = 0
# ----> 6 data = data.to(device)
#       7 optimizer.zero_grad()
#       9 out = model(data)
#
# File z:\Anaconda\envs\matgraphdb\lib\site-packages\torch_geometric\data\data.py:360, in BaseData.to(self, device, non_blocking, *args)
#     355 def to(self, device: Union[int, str], *args: str,
#     356        non_blocking: bool = False):
#     357     r"""Performs tensor device conversion, either for all attributes or
#     358     only the ones given in :obj:`*args`.
#     359     """
# --> 360     return self.apply(
#     361         lambda x: x.to(device=device, non_blocking=non_blocking), *args)
#
# File z:\Anaconda\envs\matgraphdb\lib\site-packages\torch_geometric\data\data.py:340, in BaseData.apply(self, func, *args)
#     336 r"""Applies the function :obj:`func`, either to all attributes or only
#     337 the ones given in :obj:`*args`.
#     338 """
#     339 for store in self.stores:
# --> 340     store.apply(func, *args)
#     341 return self
#
# File z:\Anaconda\envs\matgraphdb\lib\site-packages\torch_geometric\data\storage.py:201, in BaseStorage.apply(self, func, *args)
#     197 r"""Applies the function :obj:`func`, either to all attributes or only
#     198 the ones given in :obj:`*args`.
#     199 """
#     200 for key, value in self.items(*args):
# --> 201     self[key] = recursive_apply(value, func)
#     202 return self
#
# File z:\Anaconda\envs\matgraphdb\lib\site-packages\torch_geometric\data\storage.py:895, in recursive_apply(data, func)
#     893 def recursive_apply(data: Any, func: Callable) -> Any:
#     894     if isinstance(data, Tensor):
# --> 895         return func(data)
#     896     elif isinstance(data, torch.nn.utils.rnn.PackedSequence):
#     897         return func(data)
#
# File z:\Anaconda\envs\matgraphdb\lib\site-packages\torch_geometric\data\data.py:361, in BaseData.to.<locals>.<lambda>(x)
#     355 def to(self, device: Union[int, str], *args: str,
#     356        non_blocking: bool = False):
#     357     r"""Performs tensor device conversion, either for all attributes or
#     358     only the ones given in :obj:`*args`.
#     359     """
#     360     return self.apply(
# --> 361         lambda x: x.to(device=device, non_blocking=non_blocking), *args)
#
# KeyboardInterrupt:
