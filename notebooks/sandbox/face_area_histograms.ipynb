# %% [markdown]
# ## Importing package and adding path to library

# %%
# Importing package and adding path to library
import os
import sys
import numpy as np
PROJECT_DIR = os.path.abspath('../..')
SRC_DIR = os.path.join(PROJECT_DIR,'src')

sys.path.append(SRC_DIR)

# %% [markdown]
# ## import internal polyhedra

# %%
from poly_graphs_lib.utils import shapes,math
from poly_graphs_lib.data.featurization import PolyFeaturizer

# %%
test_polys = shapes.test_polys
test_names = shapes.test_names
for i, poly_name in enumerate(shapes.test_names):
    print(i, poly_name)
# Out:
# 0 tetra
# 1 cube
# 2 oct
# 3 dod
# 4 rotated_tetra
# 5 scaled_tetra
# 6 dod-like
# 7 cube-like_1
# 8 tetra-like
# 9 cube-like_2
# 10 oct-like

# %%
poly = PolyFeaturizer(vertices=test_polys[0])

# %%
n_bins =100
min_val=0
max_val=3
sigma=0.1
x = np.linspace(min_val,max_val,n_bins)
area_histograms = poly.get_verts_areas_encodings(n_bins = n_bins, min_val=min_val, max_val=max_val, sigma=sigma)
area_histograms.shape
# Out:
# (4, 100)

# %% [markdown]
# ## Plotting area histograms

# %%
import matplotlib.pyplot as plt

# %%
for area_histogram in area_histograms:
    plt.plot(x,area_histogram)

# %% [markdown]
# ### Plotting different sigma values

# %%
n_bins =100
min_val=0
max_val=3

sigmas = [0.5,0.1,0.01,0.05]

fig,axs = plt.subplots(len(sigmas))
for i,sigma in enumerate(sigmas):

    poly = PolyFeaturizer(vertices=test_polys[0])
    x = np.linspace(min_val,max_val,n_bins)
    area_histograms = poly.get_verts_areas_encodings(n_bins = n_bins, min_val=min_val, max_val=max_val, sigma=sigma)

    for area_histogram in area_histograms:
        axs[i].plot(x,area_histogram)

    axs[i].set_title(f'Sigma = {sigma}')
    if i != len(sigmas) -1:
        axs[i].get_xaxis().set_visible(False)

plt.tight_layout()

# %% [markdown]
# ### Plotting different tetrahedrons

# %%
n_bins =100
min_val=0
max_val=3

i_poly = [0,4,5,8]
polys = [test_polys[i] for i in i_poly]
poly_names = [test_names[i] for i in i_poly]
fig,axs = plt.subplots(len(i_poly))

for i,(poly,poly_name) in enumerate(zip(polys,poly_names)):

    poly = PolyFeaturizer(vertices=poly)
    x = np.linspace(min_val,max_val,n_bins)
    area_histograms = poly.get_verts_areas_encodings(n_bins = n_bins, min_val=min_val, max_val=max_val, sigma=sigma)

    for area_histogram in area_histograms:
        axs[i].plot(x,area_histogram)

    axs[i].set_title(f'Polyhedron type = {poly_name}')
    if i != len(poly_names) -1:
        axs[i].get_xaxis().set_visible(False)

plt.tight_layout()

# %% [markdown]
# ### Plotting Cubes

# %%
n_bins =100
min_val=0
max_val=3

i_poly = [1,7,9]
polys = [test_polys[i] for i in i_poly]
poly_names = [test_names[i] for i in i_poly]
fig,axs = plt.subplots(len(i_poly))

for i,(poly,poly_name) in enumerate(zip(polys,poly_names)):

    poly = PolyFeaturizer(vertices=poly)
    x = np.linspace(min_val,max_val,n_bins)
    area_histograms = poly.get_verts_areas_encodings(n_bins = n_bins, min_val=min_val, max_val=max_val, sigma=sigma)

    for area_histogram in area_histograms:
        axs[i].plot(x,area_histogram)

    axs[i].set_title(f'Polyhedron type = {poly_name}')
    if i != len(poly_names) -1:
        axs[i].get_xaxis().set_visible(False)

plt.tight_layout()

# %% [markdown]
# ### Plotting octahedron

# %%
n_bins =100
min_val=0
max_val=3

i_poly = [2,10]
polys = [test_polys[i] for i in i_poly]
poly_names = [test_names[i] for i in i_poly]
fig,axs = plt.subplots(len(i_poly))

for i,(poly,poly_name) in enumerate(zip(polys,poly_names)):

    poly = PolyFeaturizer(vertices=poly)
    x = np.linspace(min_val,max_val,n_bins)
    area_histograms = poly.get_verts_areas_encodings(n_bins = n_bins, min_val=min_val, max_val=max_val, sigma=sigma)

    for area_histogram in area_histograms:
        axs[i].plot(x,area_histogram)

    axs[i].set_title(f'Polyhedron type = {poly_name}')
    if i != len(poly_names) -1:
        axs[i].get_xaxis().set_visible(False)

plt.tight_layout()

# %% [markdown]
# ### Plotting Dodecahedron

# %%
n_bins =100
min_val=0
max_val=3

i_poly = [3,6]
polys = [test_polys[i] for i in i_poly]
poly_names = [test_names[i] for i in i_poly]
fig,axs = plt.subplots(len(i_poly))

for i,(poly,poly_name) in enumerate(zip(polys,poly_names)):

    poly = PolyFeaturizer(vertices=poly)
    x = np.linspace(min_val,max_val,n_bins)
    area_histograms = poly.get_verts_areas_encodings(n_bins = n_bins, min_val=min_val, max_val=max_val, sigma=sigma)

    for area_histogram in area_histograms:
        axs[i].plot(x,area_histogram)

    axs[i].set_title(f'Polyhedron type = {poly_name}')
    if i != len(poly_names) -1:
        axs[i].get_xaxis().set_visible(False)

plt.tight_layout()

# %% [markdown]
# ### Plotting normalization scheme

# %%
n_bins =100
min_val=0
max_val=3

normals = ['None','normal','integral']

i_poly = [0,1,2,3]
polys = [test_polys[i] for i in i_poly]
poly_names = [test_names[i] for i in i_poly]
fig,axs = plt.subplots(len(normals))

for i, normal in enumerate(normals):
    for j,(poly,poly_name) in enumerate(zip(polys,poly_names)):

        poly = PolyFeaturizer(vertices=poly)
        x = np.linspace(min_val,max_val,n_bins)
        area_histograms = poly.get_verts_areas_encodings(n_bins = n_bins, min_val=min_val, max_val=max_val, sigma=sigma)
        
        for area_histogram in area_histograms:
            if normal == 'integral':
                integral = np.trapz(area_histogram,x)
                area_histogram=area_histogram/integral
            elif normal == 'normal':
                area_histogram=area_histogram/max(area_histogram)
            elif normal == 'None':
                area_histogram=area_histogram
            axs[i].plot(x,area_histogram)

        axs[i].set_title(f'Normalization : {normal}')
        if i != len(normals) -1:
            axs[i].get_xaxis().set_visible(False)

fig.suptitle("Normalization scheme")
plt.tight_layout()
